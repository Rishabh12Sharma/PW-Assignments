# %% [markdown]
# # Kubernetes que Assignment

# %% [markdown]
# ## Kubernetes Assignment - 1
# Tasks To Be Performed-
# 1. Deploy a Kubernetes cluster for 3 nodes.
# 2. Create a NGINX deployment of 3 replicas.
#
# ![Screenshot 2026-03-25 220014.png](data:image/png;base64,...)![Screenshot 2026-03-25 220044.png](data:image/png;base64,...)![Screenshot 2026-03-25 220113.png](data:image/png;base64,...)

# %% [markdown]
# ## Kubernetes Assignment - 2
#
# Tasks To Be Performed
# 1.  Use the previous deploymen
# 2.  Create a service of type NodePort for NGINX deploymen
# 3.  Check the NodePort service on a browser to verify
#
# ![Screenshot 2026-03-25 220740.png](data:image/png;base64,...)![Screenshot 2026-03-25 220815.png](data:image/png;base64,...)![Screenshot 2026-03-25 220843.png](data:image/png;base64,...)

# %% [markdown]
# # Kubernetes Assignment - 3
#
# Tasks To Be Performed
# 1. Use the previous deploymen
# 2. Change the replicas to 5 for the deployment
#
# ![Screenshot 2026-03-25 221229.png](data:image/png;base64,...)![Screenshot 2026-03-25 221256.png](data:image/png;base64,...)

# %% [markdown]
# # Kubernetes Assignment - 4
#
# Tasks To Be Performed
# 1. Use the previous deploymen
# 2. Change the service type to ClusterIP
#
# ![Screenshot 2026-03-25 221701.png](data:image/png;base64,...)

# %% [markdown]
# # Kubernetes Assignment - 5
#
# Tasks To Be Performed
# 1.  Use the previous deployment
# 2.  Deploy an NGINX deployment of 3 replica
# 3.  Create an NGINX service of type ClusterIP
# 4.  Create an ingress service/ Apache to Apache service/ NGINX to NGINX service
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
