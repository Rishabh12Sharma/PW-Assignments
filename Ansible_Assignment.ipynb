# %% [markdown]
# # Ansible Assignment

# %% [markdown]
# ##  Install and configure Ansible, Puppet, or Chef on a local or cloud environment. Write and execute basic configuration scripts.?
# ![Screenshot 2026-03-23 103100.png](data:image/png;base64,...)
# ![Screenshot 2026-03-23 102819.png](data:image/png;base64,...)![Screenshot 2026-03-23 102908.png](data:image/png;base64,...)![Screenshot 2026-03-23 103002.png](data:image/png;base64,...)![Screenshot 2026-03-23 103025.png](data:image/png;base64,...)
