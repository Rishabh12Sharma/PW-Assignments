# %% [markdown]
# # Theoretical Overview of Docker and Containerization

# %% [markdown]
# ## 1. Install Docker and create Dockerfiles to containerize applications?
# ![Screenshot 2026-03-22 224803.png](data:image/png;base64,...)![Screenshot 2026-03-22 224900.png](data:image/png;base64,...)![Screenshot 2026-03-22 224929.png](data:image/png;base64,...)
