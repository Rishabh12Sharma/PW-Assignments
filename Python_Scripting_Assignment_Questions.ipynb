# %% [markdown]
# # Python Scripting Assignment

# %% [markdown]
# ## 1. Write Python scripts for basic file operations and data processing?
# ```bash
# # Step 1: Read file
# with open("data.txt", "r") as file:
#     lines = file.readlines()
#
# # Step 2: Process data (count frequency)
# word_count = {}
#
# for line in lines:
#     word = line.strip()   # remove spaces/newline
#     if word:
#         if word in word_count:
#             word_count[word] += 1
#         else:
#             word_count[word] = 1
#
# # Step 3: Write output to file
# with open("output.txt", "w") as file:
#     for word, count in word_count.items():
#         file.write(word + ": " + str(count) + "\n")
#
# # Step 4: Print output
# print("Processed Data:")
# print(word_count)
# ```
# ![Screenshot 2026-03-22 100806.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Develop a simple web scraper to extract data from a website?
# ```bash
# import requests
# from bs4 import BeautifulSoup
#
# # Step 1: Define URL
# url = "https://quotes.toscrape.com/"
#
# # Step 2: Send HTTP request
# response = requests.get(url)
#
# # Step 3: Parse HTML content
# soup = BeautifulSoup(response.text, "html.parser")
#
# # Step 4: Extract quotes and authors
# quotes = soup.find_all("span", class_="text")
# authors = soup.find_all("small", class_="author")
#
# # Step 5: Store data
# data = []
#
# for i in range(len(quotes)):
#     quote = quotes[i].text
#     author = authors[i].text
#     data.append({"quote": quote, "author": author})
#
# # Step 6: Print data
# for item in data:
#     print(item)
#
# # Step 7: Save data to file
# with open("quotes.txt", "w", encoding="utf-8") as file:
#     for item in data:
#         file.write(item["quote"] + " - " + item["author"] + "\n")
# ```
# ![Screenshot 2026-03-22 101308.png](data:image/png;base64,...)
