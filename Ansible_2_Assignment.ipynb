# %% [markdown]
# # Ansible-2

# %% [markdown]
# ## 1. Write Ansible playbooks to automate the setup and configuration of a web server (e.g., Apache or Nginx)?
# ![Screenshot 2026-03-23 104534.png](data:image/png;base64,...)![Screenshot 2026-03-23 104610.png](data:image/png;base64,...)![Screenshot 2026-03-23 104637.png](data:image/png;base64,...)![Screenshot 2026-03-23 104723.png](data:image/png;base64,...)
