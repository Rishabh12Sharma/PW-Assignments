# %% [markdown]
# # Introduction to Kubernetes Assignment

# %% [markdown]
# ## 1. Kubernetes Setup: Set up a local Kubernetes cluster using Minikube or a managed Kubernetes service ? (e.g., GKE, EKS).
#
# ![Screenshot 2026-03-22 220630.png](data:image/png;base64,...)![Screenshot 2026-03-22 220705.png](data:image/png;base64,...)![Screenshot 2026-03-22 220751.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Application Deployment: Deploy a simple application to your Kubernetes cluster?
# ![Screenshot 2026-03-22 221440.png](data:image/png;base64,...)
# ![Screenshot 2026-03-22 221545.png](data:image/png;base64,...)
# ![Screenshot 2026-03-22 221625.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Resource Management: Practice managing Kubernetes resources like Pods, Services, and Deployments?
# ![Screenshot 2026-03-22 222040.png](data:image/png;base64,...)![Screenshot 2026-03-22 222126.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Helm Charts: Use Helm to package and deploy applications on Kubernetes?
# ![Screenshot 2026-03-22 223254.png](data:image/png;base64,...)![Screenshot 2026-03-22 223352.png](data:image/png;base64,...)![Screenshot 2026-03-22 223442.png](data:image/png;base64,...)
